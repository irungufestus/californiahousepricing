# %%
# import the required libraries

# %%
import pandas as pd
import numpy as np
import sklearn

import matplotlib.pyplot  as plt
import seaborn as sns

# %matplotlib  inline

# %%
# let load california housing  data set

# %%
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing(as_frame=True)
housing.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
print(housing.frame)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
#from sklearn.datasets import fetch_california_housing
#housing = fetch_california_housing()
#from sklearn.datasets import fetch_openml
#housing = fetch_openml(name="house_prices", as_frame=True, parser='auto')
#housing.keys()

# %%
print(housing.data)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
print(housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block group
#         - HouseAge      median house age in block group
#         - AveRooms      average number of rooms per household
#         - AveBedrms     average number of bedrooms per household
#         - Population    block group population
#         - AveOccup      average number of household members
#         - Latitude      block group latitude
#         - Longitude     block group longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# ...

# %%
housing.feature_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %%
housing.frame.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
print(housing.target.head())
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: MedHouseVal, dtype: float64

# %%
print(housing.target_names)
# Out:
# ['MedHouseVal']

# %%
print(housing)
# Out:
# {'data':        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %% [markdown]
# # # preparing dataset

# %%
dataset=pd.DataFrame(housing.data)

# %%
dataset
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
dataset['MedHouseVal']=housing.target #add output feature in this case the median of the house value for each district

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
#statiscal data summary
dataset.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
#check missing values
dataset.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
#check correlation between independent features and the output (higly -ve or +ve correlated)
dataset.corr()
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge    -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms     0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms   -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population   0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup     0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude   -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedHouseVal  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.079809  -0.015176     0.688075
# HouseAge     0.011173  -0.108197     0.105623
# AveRooms     0.106389  -0.027540     0.151948
# ...

# %%
#plot scattered diagrams  usning seaborn library
sns.pairplot(dataset)

# %% [markdown]
# # histogram Analysis
# #We can confirm that some features have extreme values (outliers?).
# #We can as well see that the median income is helpful to distinguish high-valued from low-valued houses.

# %%
plt.scatter(dataset['MedInc'],dataset['MedHouseVal'])
plt.xlabel('MedInc')
plt.ylabel('MedHouseVal')
# Out:
# Text(0, 0.5, 'MedHouseVal')

# %%
plt.scatter(dataset['HouseAge'],dataset['MedHouseVal'])
plt.xlabel('HouseAge')
plt.ylabel('MedHouseVal')
# Out:
# Text(0, 0.5, 'MedHouseVal')

# %%
plt.scatter(dataset['Population'],dataset['MedHouseVal'])
plt.xlabel('Population')
plt.ylabel('MedHouseVal')
# Out:
# Text(0, 0.5, 'MedHouseVal')

# %%
plt.scatter(dataset['AveBedrms'],dataset['MedHouseVal'])
plt.xlabel('AveBedrms')
plt.ylabel('MedHouseVal')
# Out:
# Text(0, 0.5, 'MedHouseVal')

# %%
sns.scatterplot(data=dataset, x="Longitude", y="Latitude",size="MedHouseVal", hue="MedHouseVal",
                palette="viridis", alpha=0.5)
plt.legend(title="MedHouseVal", bbox_to_anchor=(1.05, 0.95),loc="upper left")
_ = plt.title("Median house value depending on \n their spatial location")

# %% [markdown]
# # Geolocation Observation
# High-valued houses will be located on the coast, where the big cities from California are located:
# San Diego, Los Angeles, San Jose, or San Francisco.

# %%
#check data distribution of these features by plotting their histograms
dataset.hist(figsize=(12, 10), bins=30, edgecolor="black")
plt.subplots_adjust(hspace=0.7, wspace=0.4)

# %% [markdown]
# # histogram Analysis
# Average house age, the distribution is more or less uniform average rooms, average bedrooms, average occupation, and population, the range of the data is large with unnoticeable bin/ for the largest values. It means that there are very high and few values (maybe they could be considered as outliers?). Comparing the max and 75% values, we can see a huge difference. It confirms the intuitions that there are a couple of extreme values.

# %%
#regression plot using seaborn library
sns.regplot(x='Population',y='MedHouseVal',data=dataset)
# Out:
# <Axes: xlabel='Population', ylabel='MedHouseVal'>

# %%
sns.regplot(x='HouseAge',y='MedHouseVal',data=dataset)
# Out:
# <Axes: xlabel='HouseAge', ylabel='MedHouseVal'>

# %%
sns.regplot(x='MedInc',y='MedHouseVal',data=dataset)
# Out:
# <Axes: xlabel='MedInc', ylabel='MedHouseVal'>

# %%
sns.regplot(x='AveBedrms',y='MedHouseVal',data=dataset)
# Out:
# <Axes: xlabel='AveBedrms', ylabel='MedHouseVal'>

# %%
sns.regplot(x='AveOccup',y='MedHouseVal',data=dataset)
# Out:
# <Axes: xlabel='AveOccup', ylabel='MedHouseVal'>

# %%
sns.regplot(x='AveRooms',y='MedHouseVal',data=dataset)
# Out:
# <Axes: xlabel='AveRooms', ylabel='MedHouseVal'>

# %% [markdown]
# # pair plot of all features and the target but dropping the longitude and latitude.
# We will quantize the target such that we can create proper histogram.
# Drop the unwanted columns

# %%
rng = np.random.RandomState(0)#random sampling
indices = rng.choice(np.arange(housing.frame.shape[0]), size=500,replace=False)
columns_drop = ["Longitude", "Latitude"]
subset = housing.frame.iloc[indices].drop(columns=columns_drop)
# Quantize the target and keep the midpoint for each interval
subset["MedHouseVal"] = pd.qcut(subset["MedHouseVal"], 6, retbins=False)
subset["MedHouseVal"] = subset["MedHouseVal"].apply(lambda x: x.mid)
_ = sns.pairplot(data=subset, hue="MedHouseVal", palette="viridis")

# %% [markdown]
# ## Split the variables

# %%
#independent and dependent feature(MedHouseVal)
X=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64

# %% [markdown]
# ##  Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 7061   4.1312      35.0  5.882353   0.975490      1218.0  2.985294     33.93
# 14689  2.8631      20.0  4.401210   1.076613       999.0  2.014113     32.79
# 17323  4.2026      24.0  5.617544   0.989474       731.0  2.564912     34.59
# 10056  3.1094      14.0  5.869565   1.094203       302.0  2.188406     39.26
# 15750  3.3068      52.0  4.801205   1.066265      1526.0  2.298193     37.77
# ...       ...       ...       ...        ...         ...       ...       ...
# 11284  6.3700      35.0  6.129032   0.926267       658.0  3.032258     33.78
# 11964  3.0500      33.0  6.868597   1.269488      1753.0  3.904232     34.02
# 5390   2.9344      36.0  3.986717   1.079696      1756.0  3.332068     34.03
# 860    5.7192      15.0  6.395349   1.067979      1777.0  3.178891     37.58
# 15795  2.5755      52.0  3.402576   1.058776      2619.0  2.108696     37.77
#
#        Longitude
# 7061     -118.02
# ...

# %%
y_train
# Out:
# 7061     1.93800
# 14689    1.69700
# 17323    2.59800
# 10056    1.36100
# 15750    5.00001
#           ...
# 11284    2.29200
# 11964    0.97800
# 5390     2.22100
# 860      2.83500
# 15795    3.25000
# Name: MedHouseVal, Length: 14448, dtype: float64

# %%
y_test
# Out:
# 20046    0.47700
# 3024     0.45800
# 15663    5.00001
# 20484    2.18600
# 9814     2.78000
#           ...
# 17505    2.37500
# 13512    0.67300
# 10842    2.18400
# 16559    1.19400
# 5786     2.09800
# Name: MedHouseVal, Length: 6192, dtype: float64

# %%
X_test
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20046  1.6812      25.0  4.192201   1.022284      1392.0  3.877437     36.06
# 3024   2.5313      30.0  5.039384   1.193493      1565.0  2.679795     35.14
# 15663  3.4801      52.0  3.977155   1.185877      1310.0  1.360332     37.80
# 20484  5.7376      17.0  6.163636   1.020202      1705.0  3.444444     34.28
# 9814   3.7250      34.0  5.492991   1.028037      1063.0  2.483645     36.62
# ...       ...       ...       ...        ...         ...       ...       ...
# 17505  2.9545      47.0  4.195833   1.020833       581.0  2.420833     37.36
# 13512  1.4891      41.0  4.551852   1.118519       994.0  3.681481     34.11
# 10842  3.5120      16.0  3.762287   1.075614      5014.0  2.369565     33.67
# 16559  3.6500      10.0  5.502092   1.060371      5935.0  3.547519     37.82
# 5786   3.0520      17.0  3.355781   1.019695      4116.0  2.614994     34.15
#
#        Longitude
# 20046    -119.01
# ...

# %% [markdown]
# ## standardize dataset  to the same scale unit

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.13350629,  0.50935748,  0.18106017, ..., -0.01082519,
#         -0.80568191,  0.78093406],
#        [-0.53221805, -0.67987313, -0.42262953, ..., -0.08931585,
#         -1.33947268,  1.24526986],
#        [ 0.1709897 , -0.36274497,  0.07312833, ..., -0.04480037,
#         -0.49664515, -0.27755183],
#        ...,
#        [-0.49478713,  0.58863952, -0.59156984, ...,  0.01720102,
#         -0.75885816,  0.60119118],
#        [ 0.96717102, -1.07628333,  0.39014889, ...,  0.00482125,
#          0.90338501, -1.18625198],
#        [-0.68320166,  1.85715216, -0.82965604, ..., -0.0816717 ,
#          0.99235014, -1.41592345]])

# %%
X_test
# Out:
# array([[-1.1526893 , -0.28346293, -0.50781822, ...,  0.06127763,
#          0.19166399,  0.28664112],
#        [-0.70640568,  0.11294728, -0.16252032, ..., -0.03551561,
#         -0.23911452,  0.06196251],
#        [-0.20830675,  1.85715216, -0.59546738, ..., -0.14215427,
#          1.00639726, -1.42590916],
#        ...,
#        [-0.19155996, -0.99700129, -0.6830438 , ..., -0.06058827,
#         -0.92742367,  0.8358555 ],
#        [-0.11911302, -1.47269353,  0.02607207, ...,  0.03461374,
#          1.01576201, -0.84673764],
#        [-0.43304974, -0.91771925, -0.84872893, ..., -0.0407528 ,
#         -0.70266966,  0.67109119]])

# %% [markdown]
# # model training using LinearRegression

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#print coefficent and intercepts
print(regression.coef_)
# Out:
# [ 8.49221760e-01  1.22119309e-01 -2.99558449e-01  3.48409673e-01
#  -8.84488134e-04 -4.16980388e-02 -8.93855649e-01 -8.68616688e-01]

# %%
print(regression.intercept_)
# Out:
# 2.0692396089424165

# %%
#check on which parameter model has been trained
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %% [markdown]
# # prediction with test data

# %%
reg_pred=regression.predict(X_test)

# %%
reg_pred
# Out:
# array([0.72604907, 1.76743383, 2.71092161, ..., 2.07465531, 1.57371395,
#        1.82744133])

# %% [markdown]
# # ASSUMPTIONS

# %%
#plot scatter plot for the prediction
plt.scatter(y_test,reg_pred)

# %% [markdown]
# # residuals(errors)

# %%
residuals=y_test-reg_pred

# %%
residuals
# Out:
# 20046   -0.249049
# 3024    -1.309434
# 15663    2.289088
# 20484   -0.649147
# 9814     0.173042
#            ...
# 17505    0.155059
# 13512   -0.237516
# 10842    0.109345
# 16559   -0.379714
# 5786     0.270559
# Name: MedHouseVal, Length: 6192, dtype: float64

# %%
#plot this residuals
sns.displot(residuals,kind='kde')

# %%
#plot scatter plot with respect to residuals and predictins
#results show uniform distribution
plt.scatter(reg_pred,residuals)

# %%
#performance metrix plots
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_squared_error(y_test,reg_pred))
print(mean_absolute_error(y_test,reg_pred))
print(np.sqrt(mean_absolute_error(y_test,reg_pred)))
# Out:
# 0.5305677824766755
# 0.5272474538305952
# 0.7261180715493832

# %% [markdown]
# # R Square and Adjusted R Square

# %%
#The R-squared of a regression model is positive if the model’s prediction is better than a prediction
#R^2=1-SSR/SST where  SSR=sum of square of residuals ,SST=total sum of squares

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.5957702326061662

# %%
#Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)] 
#where R2: The R2 of the model,
#n: The number of observations
#k: The number of predictor variables

# %%
#display adjusted R-squared

1-(1-score)*(len(y_test)-1)/(len(y_test) -X_test.shape[1]-1)
# Out:
# 0.5952472117200025

# %% [markdown]
# # New Data Prediction

# %%
#hosing.data.reshape(1,-1) #to provide 2d array

# %%
#X_test = [regression[:,1]].values.reshape(-1, 1)
#y = [df[:,0]].values

# %%
##Transform the new data
#scaler.transform(housing.data[0].reshape(1,-1))

# %%
#regression.predict(housing.data[0].shape(1,-1))

# %% [markdown]
# # pickling model file for deployment

# %%
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))#create pickle

# %%
pickled_model= pickle.load(open('regmodel.pkl','rb')) #load file from library

# %%
#prediction file 
pickled_model.predict(X_test)
# Out:
# array([0.72604907, 1.76743383, 2.71092161, ..., 2.07465531, 1.57371395,
#        1.82744133])
